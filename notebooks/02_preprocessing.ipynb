# %% [markdown]
# # 02 — Preprocessing
# Mirrors `ai/model/preprocess.py` for interactive iteration.

# %%
import sys
sys.path.append('../ai/model')
import preprocess

df = preprocess.load_raw()
cleaned = preprocess.clean(df)
cleaned.head()

# %%
cleaned.isna().sum()

# %%
cleaned.to_csv('../ai/data/processed/cleaned_data.csv', index=False)
